# %% [markdown]
# # First look at Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Series and DataFrames
# ---

# %%
my_Series = pd.Series([1,'cat',10.2,'dog'])
my_Series
# Out:
# 0       1
# 1     cat
# 2    10.2
# 3     dog
# dtype: object

# %%
my_Series[1]
# Out:
# 'cat'

# %%
ages = pd.Series([20,53,68], index=['John', 'Allen', 'Mary'])
ages
# Out:
# John     20
# Allen    53
# Mary     68
# dtype: int64

# %%
ages['Mary']
# Out:
# 68

# %%
df = pd.DataFrame({
    'user' : [1,2,3],
    'age' : [24,54,17],
    'sex' : ['F','F','M'],
    'occupation' : ['technician','musician','student']
})

# %%
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %%
df.set_index('user')
# Out:
#       age sex  occupation
# user
# 1      24   F  technician
# 2      54   F    musician
# 3      17   M     student

# %%
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %%
# df.set_index('user', inplace = True)  
## an indication that the original DataFrame has been modified. 
# made in-place (meaning that the original object is modified) 
# pandas library is that most of its methods return a new copy of the modified object.

# %%
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %%
df.set_index('sex')
# Out:
#      user  age  occupation
# sex
# F       1   24  technician
# F       2   54    musician
# M       3   17     student

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
# user          3 non-null int64
# age           3 non-null int64
# sex           3 non-null object
# occupation    3 non-null object
# dtypes: int64(2), object(2)
# memory usage: 176.0+ bytes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %%
df.head(2)
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician

# %%
df.shape
# Out:
# (3, 4)

# %%
#displaying the number of rows
df.shape[0]
# Out:
# 3

# %%
#displaying the number of columns
df.shape[1]
# Out:
# 4

# %%
#displaying the labels of all the columns
df.columns
# Out:
# Index(['user', 'age', 'sex', 'occupation'], dtype='object')

# %%
#displaying the data types of each column
df.dtypes
# Out:
# user           int64
# age            int64
# sex           object
# occupation    object
# dtype: object

# %%
df.columns
# Out:
# Index(['user', 'age', 'sex', 'occupation'], dtype='object')

# %%
df.dtypes
# Out:
# user           int64
# age            int64
# sex           object
# occupation    object
# dtype: object

# %%
df.describe()
#some quick statistics about numerical columns
# Out:
#        user        age
# count   3.0   3.000000
# mean    2.0  31.666667
# std     1.0  19.655364
# min     1.0  17.000000
# 25%     1.5  20.500000
# 50%     2.0  24.000000
# 75%     2.5  39.000000
# max     3.0  54.000000

# %%
df['occupation']
# Out:
# 0    technician
# 1      musician
# 2       student
# Name: occupation, dtype: object

# %% [markdown]
# # Importing data from files

# %%
df = pd.read_csv('Mountains.csv')
df
# Out:
#      Rank                                  Mountain  Height (m)  Height (ft)  \
# 0       1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 1       2                K2 / Qogir / Godwin Austen        8611        28251
# 2       3                             Kangchenjunga        8586        28169
# 3       4                                    Lhotse        8516        27940
# 4       5                                    Makalu        8485        27838
# 5       6                                   Cho Oyu        8188        26864
# 6       7                              Dhaulagiri I        8167        26795
# 7       8                                   Manaslu        8163        26781
# 8       9                              Nanga Parbat        8126        26660
# 9      10                               Annapurna I        8091        26545
# 10     11           Gasherbrum I / Hidden Peak / K5        8080        26509
# ...

# %%
df1 = pd.read_csv('Mountains.csv', header=None)
df1
# Out:
#        0                                         1           2            3   \
# 0    Rank                                  Mountain  Height (m)  Height (ft)
# 1       1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 2       2                K2 / Qogir / Godwin Austen        8611        28251
# 3       3                             Kangchenjunga        8586        28169
# 4       4                                    Lhotse        8516        27940
# 5       5                                    Makalu        8485        27838
# 6       6                                   Cho Oyu        8188        26864
# 7       7                              Dhaulagiri I        8167        26795
# 8       8                                   Manaslu        8163        26781
# 9       9                              Nanga Parbat        8126        26660
# 10     10                               Annapurna I        8091        26545
# ...

# %%
df2 = pd.read_csv('Mountains.csv', names=['Header1', 'Header2'])
# provide our own list of column headers
df2
# Out:
#                                                                                                                                                                                     Header1  \
# Rank Mountain                                 Height (m) Height (ft) Prominence (m) Range                        Coordinates             Parent mountain    First ascent  Ascents bef. 2004
# 1    Mount Everest / Sagarmatha / Chomolungma 8848       29029       8848           Mahalangur Himalaya          27°59′17″N 86°55′31″E﻿  NaN                1953                     >>145
# 2    K2 / Qogir / Godwin Austen               8611       28251       4017           Baltoro Karakoram            35°52′53″N 76°30′48″E﻿  Mount Everest      1954                         45
# 3    Kangchenjunga                            8586       28169       3922           Kangchenjunga Himalaya       27°42′12″N 88°08′51″E﻿  Mount Everest      1955                         38
# ...

# %%
df3 = pd.read_csv('Mountains.csv', na_values=['?'])
#  the code below imports the csv file and treats all question mark symbols as missing data.
df3
# Out:
#      Rank                                  Mountain  Height (m)  Height (ft)  \
# 0       1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 1       2                K2 / Qogir / Godwin Austen        8611        28251
# 2       3                             Kangchenjunga        8586        28169
# 3       4                                    Lhotse        8516        27940
# 4       5                                    Makalu        8485        27838
# 5       6                                   Cho Oyu        8188        26864
# 6       7                              Dhaulagiri I        8167        26795
# 7       8                                   Manaslu        8163        26781
# 8       9                              Nanga Parbat        8126        26660
# 9      10                               Annapurna I        8091        26545
# 10     11           Gasherbrum I / Hidden Peak / K5        8080        26509
# ...

# %%
dfExcel = pd.read_excel('Mountains.xlsx')
dfExcel
# Other supported files include JSON, HTML, SAS, and SQL.
# Out:
#      Rank       Mountain     Height    (m)    Height.1                (ft)  \
# 0       1          Mount    Everest      /  Sagarmatha                   /
# 1       2             K2          /  Qogir           /              Godwin
# 2       3  Kangchenjunga       8586  28169        3922       Kangchenjunga
# 3       4         Lhotse       8516  27940         610          Mahalangur
# 4       5         Makalu       8485  27838        2386          Mahalangur
# 5       6            Cho        Oyu   8188       26864                2340
# 6       7     Dhaulagiri          I   8167       26795                3357
# 7       8        Manaslu       8163  26781        3092             Manaslu
# 8       9          Nanga     Parbat   8126       26660                4608
# 9      10      Annapurna          I   8091       26545                2984
# 10     11     Gasherbrum          I      /      Hidden                Peak
# ...

# %% [markdown]
# Manipulating the data
# ---

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.arange(9).reshape(3,3), columns=['a','b', 'c'])
df
# Out:
#    a  b  c
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %% [markdown]
# * to drop rows: by specifying a list of row indices corresponding to the rows to be dropped together with the parameter axis=0 which tells pandas that we are dropping rows
# *  to drop columns: by specifying a list of column labels corresponding to the columns to be dropped together with the parameter axis=1 which tells pandas that we are dropping columns
#
# * 删除行：通过指定与要删除的行相对应的行索引列表以及参数axis = 0来告诉我们正在删除行
# * 删除列：通过指定与要删除的列相对应的列标签列表以及参数axis = 1来告诉我们要删除列
#
# *  the method always returns a new object with the dropped values missing and the original DataFrame is not modified.

# %%
df.drop(0, axis=0) # drop 0 row   drop the first row
# Out:
#    a  b  c
# 1  3  4  5
# 2  6  7  8

# %%
df.drop([0,2], axis=0) # drop the first and third row
# Out:
#    a  b  c
# 1  3  4  5

# %%
df.drop(['b','c'], axis=1)   # drop columns we just specify the label added pairwise as expected.
# Out:
#    a
# 0  0
# 1  3
# 2  6

# %%
df['a'] + df['b']  #Arithmetic operations 算术运算  按预期成对添加。
# Out:
# 0     1
# 1     7
# 2    13
# dtype: int32

# %%
df['a'].add(df['b'])  # 
   # sub()
   # div()
    #mul()
# Out:
# 0     1
# 1     7
# 2    13
# dtype: int32

# %%
df.add(df.loc[0:1,:])  
#The function loc is used to select entries by index by first specifying the rows that we want and then the columns that we want.
# Out:
#      a    b     c
# 0  0.0  2.0   4.0
# 1  6.0  8.0  10.0
# 2  NaN  NaN   NaN

# %%
df.add(df.loc[0:1,:], fill_value=0)
#now there are no row indices which do not overlap anymore, and the addition can be performed element wise without resulting in NaN values.
# Out:
#      a    b     c
# 0  0.0  2.0   4.0
# 1  6.0  8.0  10.0
# 2  6.0  7.0   8.0

# %% [markdown]
# # Concatenating DataFrames 串联数据框
#
#  *   the DataFrames have the same columns and we want to stack them one on top of the other
#  *   the DataFrames have the same rows and we want to glue them one next to the other
#
# * DataFrames 具有相同的列，我们希望将它们一个堆叠在另一个之上
# * DataFrames具有相同的行，我们希望将它们彼此粘合在一起

# %%
df1= pd.DataFrame([['Mark', 50], ['Kate', 46]],
                 columns=['name', 'age'])
df2 = pd.DataFrame([['Jon', 3], ['David', 4]],
                columns=['name', 'age'])

# %%
df1
# Out:
#    name  age
# 0  Mark   50
# 1  Kate   46

# %%
df2
# Out:
#     name  age
# 0    Jon    3
# 1  David    4

# %%
pd.concat([df1,df2])  #  join them together
# Out:
#     name  age
# 0   Mark   50
# 1   Kate   46
# 0    Jon    3
# 1  David    4

# %%
df3 = pd.DataFrame(['writer', 'journalist'], columns=['occupation'])
df3
# Out:
#    occupation
# 0      writer
# 1  journalist

# %%
pd.concat([df1, df2, df3], axis=1) # combine two different DataFrames along the columns.
# Out:
#    name  age   name  age  occupation
# 0  Mark   50    Jon    3      writer
# 1  Kate   46  David    4  journalist

# %% [markdown]
# Indexing, selecting and filtering
# ---
#
#
# Essentially a DataFrame is composed of the following three elements
#
#     the index labels (these are the bold numbers from 0 to 9 on the left-hand side of the table)
#     the column names (these are the bold names on the top of the table)
#     the data itself (this is everything else inside the actual cells of the table)
# 本质上，DataFrame由以下三个元素组成
#
#      索引标签（这些是表格左侧从0到9的粗体数字）
#      列名称（这些是表格顶部的粗体名称）
#      数据本身（这是表的实际单元格中的所有其他内容

# %%
# We will work on a subset of the columns
columns = [
    'Mountain', 'Height (m)', 'Range', 'Coordinates', 'Parent mountain',
    'First ascent', 'Ascents bef. 2004', 'Failed attempts bef. 2004'
]

# Load the DataFrame, we will work on the first 10 rows (ten highest mountains)
df = pd.read_csv('Mountains.csv', nrows=10, usecols=columns)
df
# Out:
#                                    Mountain  Height (m)  \
# 0  Mount Everest / Sagarmatha / Chomolungma        8848
# 1                K2 / Qogir / Godwin Austen        8611
# 2                             Kangchenjunga        8586
# 3                                    Lhotse        8516
# 4                                    Makalu        8485
# 5                                   Cho Oyu        8188
# 6                              Dhaulagiri I        8167
# 7                                   Manaslu        8163
# 8                              Nanga Parbat        8126
# 9                               Annapurna I        8091
#
#                     Range              Coordinates Parent mountain  \
# 0     Mahalangur Himalaya  27°59′17″N 86°55′31″E﻿              NaN
# 1       Baltoro Karakoram  35°52′53″N 76°30′48″E﻿    Mount Everest
# 2  Kangchenjunga Himalaya  27°42′12″N 88°08′51″E﻿    Mount Everest
# 3     Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿    Mount Everest
# ...

# %%
df.set_index('Mountain', inplace=True)
df
# Out:
#                                           Height (m)                   Range  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma        8848     Mahalangur Himalaya
# K2 / Qogir / Godwin Austen                      8611       Baltoro Karakoram
# Kangchenjunga                                   8586  Kangchenjunga Himalaya
# Lhotse                                          8516     Mahalangur Himalaya
# Makalu                                          8485     Mahalangur Himalaya
# Cho Oyu                                         8188     Mahalangur Himalaya
# Dhaulagiri I                                    8167     Dhaulagiri Himalaya
# Manaslu                                         8163        Manaslu Himalaya
# Nanga Parbat                                    8126   Nanga Parbat Himalaya
# Annapurna I                                     8091      Annapurna Himalaya
#
#                                                       Coordinates  \
# Mountain
# ...

# %%
df.index
# Out:
# Index(['Mount Everest / Sagarmatha / Chomolungma',
#        'K2 / Qogir / Godwin Austen', 'Kangchenjunga', 'Lhotse', 'Makalu',
#        'Cho Oyu', 'Dhaulagiri I', 'Manaslu', 'Nanga Parbat', 'Annapurna I'],
#       dtype='object', name='Mountain')

# %%
df.columns
# Out:
# Index(['Height (m)', 'Range', 'Coordinates', 'Parent mountain', 'First ascent',
#        'Ascents bef. 2004', 'Failed attempts bef. 2004'],
#       dtype='object')

# %% [markdown]
# * The attribute operator . to select columns

# %%
df.Range
# Out:
# Mountain
# Mount Everest / Sagarmatha / Chomolungma       Mahalangur Himalaya
# K2 / Qogir / Godwin Austen                       Baltoro Karakoram
# Kangchenjunga                               Kangchenjunga Himalaya
# Lhotse                                         Mahalangur Himalaya
# Makalu                                         Mahalangur Himalaya
# Cho Oyu                                        Mahalangur Himalaya
# Dhaulagiri I                                   Dhaulagiri Himalaya
# Manaslu                                           Manaslu Himalaya
# Nanga Parbat                                 Nanga Parbat Himalaya
# Annapurna I                                     Annapurna Himalaya
# Name: Range, dtype: object

# %%
df.all
# Out:
# <bound method DataFrame.all of                                           Height (m)                   Range  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma        8848     Mahalangur Himalaya
# K2 / Qogir / Godwin Austen                      8611       Baltoro Karakoram
# Kangchenjunga                                   8586  Kangchenjunga Himalaya
# Lhotse                                          8516     Mahalangur Himalaya
# Makalu                                          8485     Mahalangur Himalaya
# Cho Oyu                                         8188     Mahalangur Himalaya
# Dhaulagiri I                                    8167     Dhaulagiri Himalaya
# Manaslu                                         8163        Manaslu Himalaya
# Nanga Parbat                                    8126   Nanga Parbat Himalaya
# Annapurna I                                     8091      Annapurna Himalaya
#
#                                                       Coordinates  \
# Mountain
# ...

# %%
getattr(df, 'Height (m)')  #white spaces    attributes
# Out:
# Mountain
# Mount Everest / Sagarmatha / Chomolungma    8848
# K2 / Qogir / Godwin Austen                  8611
# Kangchenjunga                               8586
# Lhotse                                      8516
# Makalu                                      8485
# Cho Oyu                                     8188
# Dhaulagiri I                                8167
# Manaslu                                     8163
# Nanga Parbat                                8126
# Annapurna I                                 8091
# Name: Height (m), dtype: int64

# %%
getattr(df, 'Parent mountain')
# Out:
# Mountain
# Mount Everest / Sagarmatha / Chomolungma              NaN
# K2 / Qogir / Godwin Austen                  Mount Everest
# Kangchenjunga                               Mount Everest
# Lhotse                                      Mount Everest
# Makalu                                      Mount Everest
# Cho Oyu                                     Mount Everest
# Dhaulagiri I                                           K2
# Manaslu                                           Cho Oyu
# Nanga Parbat                                   Dhaulagiri
# Annapurna I                                       Cho Oyu
# Name: Parent mountain, dtype: object

# %% [markdown]
# * The index operator [ ] to select columns

# %%
df['Height (m)']
# Out:
# Mountain
# Mount Everest / Sagarmatha / Chomolungma    8848
# K2 / Qogir / Godwin Austen                  8611
# Kangchenjunga                               8586
# Lhotse                                      8516
# Makalu                                      8485
# Cho Oyu                                     8188
# Dhaulagiri I                                8167
# Manaslu                                     8163
# Nanga Parbat                                8126
# Annapurna I                                 8091
# Name: Height (m), dtype: int64

# %%
df[['Height (m)', 'Range', 'Coordinates']]
#As soon as we select more than one column, the returned object is a DataFrame as opposed to a Series.
#一旦选择多个列，返回的对象就是一个DataFrame而不是Series。
# Out:
#                                           Height (m)                   Range  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma        8848     Mahalangur Himalaya
# K2 / Qogir / Godwin Austen                      8611       Baltoro Karakoram
# Kangchenjunga                                   8586  Kangchenjunga Himalaya
# Lhotse                                          8516     Mahalangur Himalaya
# Makalu                                          8485     Mahalangur Himalaya
# Cho Oyu                                         8188     Mahalangur Himalaya
# Dhaulagiri I                                    8167     Dhaulagiri Himalaya
# Manaslu                                         8163        Manaslu Himalaya
# Nanga Parbat                                    8126   Nanga Parbat Himalaya
# Annapurna I                                     8091      Annapurna Himalaya
#
#                                                       Coordinates
# Mountain
# ...

# %%
df[2:8]  # a[start:stop:step]  2-7 without 8
# Out:
#                Height (m)                   Range              Coordinates  \
# Mountain
# Kangchenjunga        8586  Kangchenjunga Himalaya  27°42′12″N 88°08′51″E﻿
# Lhotse               8516     Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿
# Makalu               8485     Mahalangur Himalaya  27°53′23″N 87°05′20″E﻿
# Cho Oyu              8188     Mahalangur Himalaya  28°05′39″N 86°39′39″E﻿
# Dhaulagiri I         8167     Dhaulagiri Himalaya  28°41′48″N 83°29′35″E﻿
# Manaslu              8163        Manaslu Himalaya  28°33′00″N 84°33′35″E﻿
#
#               Parent mountain  First ascent Ascents bef. 2004  \
# Mountain
# Kangchenjunga   Mount Everest          1955                38
# Lhotse          Mount Everest          1956                26
# Makalu          Mount Everest          1955                45
# Cho Oyu         Mount Everest          1954                79
# Dhaulagiri I               K2          1960                51
# ...

# %%
df['Lhotse':'Manaslu']     # slicing notation becomes inclusive of both the start and end value.
# Out:
#               Height (m)                Range              Coordinates  \
# Mountain
# Lhotse              8516  Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿
# Makalu              8485  Mahalangur Himalaya  27°53′23″N 87°05′20″E﻿
# Cho Oyu             8188  Mahalangur Himalaya  28°05′39″N 86°39′39″E﻿
# Dhaulagiri I        8167  Dhaulagiri Himalaya  28°41′48″N 83°29′35″E﻿
# Manaslu             8163     Manaslu Himalaya  28°33′00″N 84°33′35″E﻿
#
#              Parent mountain  First ascent Ascents bef. 2004  \
# Mountain
# Lhotse         Mount Everest          1956                26
# Makalu         Mount Everest          1955                45
# Cho Oyu        Mount Everest          1954                79
# Dhaulagiri I              K2          1960                51
# Manaslu              Cho Oyu          1956                49
#
#               Failed attempts bef. 2004
# Mountain
# Lhotse                               26
# Makalu                               52
# ...

# %%
df
# Out:
#                                           Height (m)                   Range  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma        8848     Mahalangur Himalaya
# K2 / Qogir / Godwin Austen                      8611       Baltoro Karakoram
# Kangchenjunga                                   8586  Kangchenjunga Himalaya
# Lhotse                                          8516     Mahalangur Himalaya
# Makalu                                          8485     Mahalangur Himalaya
# Cho Oyu                                         8188     Mahalangur Himalaya
# Dhaulagiri I                                    8167     Dhaulagiri Himalaya
# Manaslu                                         8163        Manaslu Himalaya
# Nanga Parbat                                    8126   Nanga Parbat Himalaya
# Annapurna I                                     8091      Annapurna Himalaya
#
#                                                       Coordinates  \
# Mountain
# ...

# %% [markdown]
# * simultaneously select a subset of the rows and a subset of the columns. This is what the next two operators help us achieve.

# %%
df.iloc[:, 2:6]   # 2-5   df.iloc[rows, columns]
# Out:
#                                                       Coordinates  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma  27°59′17″N 86°55′31″E﻿
# K2 / Qogir / Godwin Austen                35°52′53″N 76°30′48″E﻿
# Kangchenjunga                             27°42′12″N 88°08′51″E﻿
# Lhotse                                    27°57′42″N 86°55′59″E﻿
# Makalu                                    27°53′23″N 87°05′20″E﻿
# Cho Oyu                                   28°05′39″N 86°39′39″E﻿
# Dhaulagiri I                              28°41′48″N 83°29′35″E﻿
# Manaslu                                   28°33′00″N 84°33′35″E﻿
# Nanga Parbat                              35°14′14″N 74°35′21″E﻿
# Annapurna I                               28°35′44″N 83°49′13″E﻿
#
#                                          Parent mountain  First ascent  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma             NaN          1953
# K2 / Qogir / Godwin Austen                 Mount Everest          1954
# ...

# %% [markdown]
#     single position value ex. 3
#     a list of position values ex. [3, 5, 8]
#     a slice of position values ex. 3:8
#     the : symbol to select all the rows and/or columns

# %%
df.iloc[::2, 2:]
# ::2 for the rows which selects every second row from the first to and up to the last.
# 2: for the columns which selects every column from position 2 to the last column of the DataFrame.
# Out:
#                                                       Coordinates  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma  27°59′17″N 86°55′31″E﻿
# Kangchenjunga                             27°42′12″N 88°08′51″E﻿
# Makalu                                    27°53′23″N 87°05′20″E﻿
# Dhaulagiri I                              28°41′48″N 83°29′35″E﻿
# Nanga Parbat                              35°14′14″N 74°35′21″E﻿
#
#                                          Parent mountain  First ascent  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma             NaN          1953
# Kangchenjunga                              Mount Everest          1955
# Makalu                                     Mount Everest          1955
# Dhaulagiri I                                          K2          1960
# Nanga Parbat                                  Dhaulagiri          1953
#
#                                          Ascents bef. 2004  \
# Mountain
# ...

# %% [markdown]
# df.loc[rows, columns]
#
# where rows can now take the form of
#
#     a single index label ex. 'Makalu'
#     a list of index labels ex. ['Makalu', 'Nanga Parbat']
#     a slice of index labels ex. 'Makalu':'Nanga Parbat'
#     the : symbol to select all the rows
#
# and columns can take the form of
#
#     a single column name ex. 'Range'
#     a list of column names ex. ['Range', 'Parent mountain']
#     a slice of column names ex. 'Height (m)':'First ascent'
#     the : symbol to select all the columns

# %%
df.loc[:, 'Height (m)':'First ascent']
# Out:
#                                           Height (m)                   Range  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma        8848     Mahalangur Himalaya
# K2 / Qogir / Godwin Austen                      8611       Baltoro Karakoram
# Kangchenjunga                                   8586  Kangchenjunga Himalaya
# Lhotse                                          8516     Mahalangur Himalaya
# Makalu                                          8485     Mahalangur Himalaya
# Cho Oyu                                         8188     Mahalangur Himalaya
# Dhaulagiri I                                    8167     Dhaulagiri Himalaya
# Manaslu                                         8163        Manaslu Himalaya
# Nanga Parbat                                    8126   Nanga Parbat Himalaya
# Annapurna I                                     8091      Annapurna Himalaya
#
#                                                       Coordinates  \
# Mountain
# ...

# %%
df.loc[:, 'Height (m)':'First ascent':2]
# Out:
#                                           Height (m)              Coordinates  \
# Mountain
# Mount Everest / Sagarmatha / Chomolungma        8848  27°59′17″N 86°55′31″E﻿
# K2 / Qogir / Godwin Austen                      8611  35°52′53″N 76°30′48″E﻿
# Kangchenjunga                                   8586  27°42′12″N 88°08′51″E﻿
# Lhotse                                          8516  27°57′42″N 86°55′59″E﻿
# Makalu                                          8485  27°53′23″N 87°05′20″E﻿
# Cho Oyu                                         8188  28°05′39″N 86°39′39″E﻿
# Dhaulagiri I                                    8167  28°41′48″N 83°29′35″E﻿
# Manaslu                                         8163  28°33′00″N 84°33′35″E﻿
# Nanga Parbat                                    8126  35°14′14″N 74°35′21″E﻿
# Annapurna I                                     8091  28°35′44″N 83°49′13″E﻿
#
#                                           First ascent
# Mountain
# ...

# %% [markdown]
# # Boolean selection of rows using the [ ] operator

# %%
df['Parent mountain'] == 'Mount Everest'
# Out:
# Mountain
# Mount Everest / Sagarmatha / Chomolungma    False
# K2 / Qogir / Godwin Austen                   True
# Kangchenjunga                                True
# Lhotse                                       True
# Makalu                                       True
# Cho Oyu                                      True
# Dhaulagiri I                                False
# Manaslu                                     False
# Nanga Parbat                                False
# Annapurna I                                 False
# Name: Parent mountain, dtype: bool

# %%
df['Parent mountain']
# Out:
# Mountain
# Mount Everest / Sagarmatha / Chomolungma              NaN
# K2 / Qogir / Godwin Austen                  Mount Everest
# Kangchenjunga                               Mount Everest
# Lhotse                                      Mount Everest
# Makalu                                      Mount Everest
# Cho Oyu                                     Mount Everest
# Dhaulagiri I                                           K2
# Manaslu                                           Cho Oyu
# Nanga Parbat                                   Dhaulagiri
# Annapurna I                                       Cho Oyu
# Name: Parent mountain, dtype: object

# %%
df[df['Parent mountain'] == 'Mount Everest']
# Out:
#                             Height (m)                   Range  \
# Mountain
# K2 / Qogir / Godwin Austen        8611       Baltoro Karakoram
# Kangchenjunga                     8586  Kangchenjunga Himalaya
# Lhotse                            8516     Mahalangur Himalaya
# Makalu                            8485     Mahalangur Himalaya
# Cho Oyu                           8188     Mahalangur Himalaya
#
#                                         Coordinates Parent mountain  \
# Mountain
# K2 / Qogir / Godwin Austen  35°52′53″N 76°30′48″E﻿    Mount Everest
# Kangchenjunga               27°42′12″N 88°08′51″E﻿    Mount Everest
# Lhotse                      27°57′42″N 86°55′59″E﻿    Mount Everest
# Makalu                      27°53′23″N 87°05′20″E﻿    Mount Everest
# Cho Oyu                     28°05′39″N 86°39′39″E﻿    Mount Everest
#
#                             First ascent Ascents bef. 2004  \
# Mountain
# K2 / Qogir / Godwin Austen          1954                45
# ...

# %% [markdown]
#     & for and
#     | for or
#     ~ for not

# %%
# Mountains with Mount Everest as parent with a first ascent after 1955
df[(df['Parent mountain'] == 'Mount Everest') & (df['First ascent'] > 1955)]
# Out:
#           Height (m)                Range              Coordinates  \
# Mountain
# Lhotse          8516  Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿
#
#          Parent mountain  First ascent Ascents bef. 2004  \
# Mountain
# Lhotse     Mount Everest          1956                26
#
#           Failed attempts bef. 2004
# Mountain
# Lhotse                           26

# %%
df.loc[(df['Parent mountain'] == 'Mount Everest') & (df['First ascent'] > 1955), :]
# Out:
#           Height (m)                Range              Coordinates  \
# Mountain
# Lhotse          8516  Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿
#
#          Parent mountain  First ascent Ascents bef. 2004  \
# Mountain
# Lhotse     Mount Everest          1956                26
#
#           Failed attempts bef. 2004
# Mountain
# Lhotse                           26

# %%
df.loc[(df['Parent mountain'] == 'Mount Everest') & (df['First ascent'] > 1955), 'Height (m)':'Range']
# Out:
#           Height (m)                Range
# Mountain
# Lhotse          8516  Mahalangur Himalaya

# %%
col_criteria = [True, False, False, False, True, True, False]
df.loc[df['Parent mountain'] == 'Mount Everest', col_criteria]
# Out:
#                             Height (m)  First ascent Ascents bef. 2004
# Mountain
# K2 / Qogir / Godwin Austen        8611          1954                45
# Kangchenjunga                     8586          1955                38
# Lhotse                            8516          1956                26
# Makalu                            8485          1955                45
# Cho Oyu                           8188          1954                79

# %% [markdown]
# Views vs copies
# ---

# %%
df= pd.DataFrame({
    'user': [1,2,3],
    'age': [24,54,17],
    'sex': ['F','F','M'],
    'occupation': ['technician','musician','student']
})
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %%
df[df.sex=='F']
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician

# %%
df[df.sex=='F'].sex
# Out:
# 0    F
# 1    F
# Name: sex, dtype: object

# %%
df[df.sex=='F'].sex = 'Female'
# Out:
# D:\0_Anaconda\envs\exts-ml\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df    # it remains unchanged!  This is because our selection method returned a copy

# chained assignment" because we are essentially performing two chained operations to select the entries:
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %%
df.loc[df.sex=='F','sex']  
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %% [markdown]
# * we use the loc() method instead!
# * using the iloc(), loc() method set some new values

# %%
df.loc[df.sex=='F','sex'] = 'Female'  # change then original one!!!!!!
df
# Out:
#    user  age     sex  occupation
# 0     1   24  Female  technician
# 1     2   54  Female    musician
# 2     3   17       M     student

# %% [markdown]
# * Let's go back to our original DataFrame

# %%
df = pd.DataFrame( {
    'user': [1,2,3], 
    'age': [24,54,17], 
    'sex': ['F','F','M'], 
    'occupation': ['technician','musician','student']
})
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %%
df2 = df.loc[df.sex=='F']
df2
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician

# %% [markdown]
#  When we define df2 to be a subset of df, pandas does not know if once again this subset is a copy or a view. So when later on in our code we attempt to modify this subset, we get the same warning, since pandas does not know if we are modifying just df2, or both df and df2

# %%
df2.loc[0:1,'sex']='Female'
# Out:
# D:\0_Anaconda\envs\exts-ml\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df2 = df.loc[df.sex=='F'].copy()   ## copy()
df2
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician

# %%
df2.loc[0:1,'sex']='Female'
df2
# Out:
#    user  age     sex  occupation
# 0     1   24  Female  technician
# 1     2   54  Female    musician

# %%
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %% [markdown]
# Applying functions
# ---
#
#     map()
#     apply()
#     applymap()

# %%
df = pd.DataFrame( {
    'user': [1, 2, 3], 
    'age': [24, 54, 17], 
    'sex': ['F', 'F', 'M'], 
    'occupation': ['technician', 'musician', 'student']
})
df
# Out:
#    user  age sex  occupation
# 0     1   24   F  technician
# 1     2   54   F    musician
# 2     3   17   M     student

# %% [markdown]
# * The method map() applies to Series and is used to replace the existing value in a series with different values.

# %%
df['sex'] = df['sex'].map({'F': 'Female', 'M': 'Male'})
df
# Out:
#    user  age     sex  occupation
# 0     1   24  Female  technician
# 1     2   54  Female    musician
# 2     3   17    Male     student

# %%
df['sex'].map({'Female': 1})  
# we must ensure that we pass all of the values to the dictionary.
# Out:
# 0    1.0
# 1    1.0
# 2    NaN
# Name: sex, dtype: float64

# %% [markdown]
# * The replace() can be applied to both a Series or a DataFrame. It can be used to replace either all the values or a subset of the values. When replacing only a subset of the values, it leaves the other values as is.

# %%
df['sex'].replace('Female', '1')
# Out:
# 0       1
# 1       1
# 2    Male
# Name: sex, dtype: object

# %%
df2 = pd.DataFrame(
    data=np.arange(9).reshape(3, 3), columns=['a', 'b', 'c'])
df2
# Out:
#    a  b  c
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %% [markdown]
# * This apply() method is both for Series and DataFrame. It is used for applying a function to either the rows or the columns.
#
# * along axis 0 meaning down the data frame which will return the sum along each column
# * along axis 1 meaning across the data frame which will return the sum along each row

# %%
df2.apply(sum, axis=0)
# Out:
# a     9
# b    12
# c    15
# dtype: int64

# %%
df2.apply(sum, axis=1)
# Out:
# 0     3
# 1    12
# 2    21
# dtype: int64

# %%
# Finds the maximum entry in each row
df2.apply(np.max, axis = 1)
# Out:
# 0    2
# 1    5
# 2    8
# dtype: int64

# %%
# Find the mean of each column
df2.apply(np.mean, axis = 0)
# Out:
# a    3.0
# b    4.0
# c    5.0
# dtype: float64

# %% [markdown]
# *  applymap() method is used to apply a function to every element of a DataFrame.
#
# * One thing to keep in mind is that while applymap() is a convenient and versatile method, it can be quite inefficient for larger datasets, basically because it has to run the function on each individual element of the DataFrame. It is always best whenever possible to try and use vectorized operations.

# %%
def my_func(x):
    if x > 5:
        size = 'Large'
    elif x >3:
        size = 'Medium'
    else:
        size = 'Small'
    return size

# %%
df2.applymap(my_func)
# Out:
#        a       b       c
# 0  Small   Small   Small
# 1  Small  Medium  Medium
# 2  Large   Large   Large

# %% [markdown]
# Sorting
# ---
#
# There are two main types of sorting that we will consider:
#
#     by index or label
#     by value

# %%
df = pd.DataFrame({'A':[3,6,1,12,3],'B':[0,0,7,5,6],'C':[10,4,5,8,2]})
df
# Out:
#     A  B   C
# 0   3  0  10
# 1   6  0   4
# 2   1  7   5
# 3  12  5   8
# 4   3  6   2

# %%
df.sort_index()
# Out:
#     A  B   C
# 0   3  0  10
# 1   6  0   4
# 2   1  7   5
# 3  12  5   8
# 4   3  6   2

# %%
df.sort_index(ascending=False)   # descending order
# Out:
#     A  B   C
# 4   3  6   2
# 3  12  5   8
# 2   1  7   5
# 1   6  0   4
# 0   3  0  10

# %% [markdown]
#  * We could also choose to sort by column labels instead. In this case, since our labels are strings they will be sorted in lexicographical order, where once again the default is in ascending order.
#  * 我们也可以选择按列标签排序。 在这种情况下，由于我们的标签是字符串，因此它们将按字典顺序进行排序，其中默认值再次按升序排列。

# %%
df.sort_index(ascending=False, axis=1)
# Out:
#     C  B   A
# 0  10  0   3
# 1   4  0   6
# 2   5  7   1
# 3   8  5  12
# 4   2  6   3

# %%
df['A']
# Out:
# 0     3
# 1     6
# 2     1
# 3    12
# 4     3
# Name: A, dtype: int64

# %%
df['A'].sort_values()  # ONLY  first column
# Out:
# 2     1
# 0     3
# 4     3
# 1     6
# 3    12
# Name: A, dtype: int64

# %%
df.sort_values('A')  #Sort by values  A column for entire DataFrame
# Out:
#     A  B   C
# 2   1  7   5
# 0   3  0  10
# 4   3  6   2
# 1   6  0   4
# 3  12  5   8

# %%
df.sort_values(['A','C'])   #Sort by values  A, C column
# Out:
#     A  B   C
# 2   1  7   5
# 4   3  6   2
# 0   3  0  10
# 1   6  0   4
# 3  12  5   8

# %% [markdown]
# Grouping
# ---

# %%
df = pd.DataFrame({
       'A' : ['dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog'],
       'B' : ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],
       'C' : np.random.randint(10, size=8)})
df
# Out:
#      A      B  C
# 0  dog    one  0
# 1  cat    one  0
# 2  dog    two  2
# 3  cat  three  9
# 4  dog    two  1
# 5  cat    two  1
# 6  dog    one  4
# 7  dog  three  6

# %%
df['C'].mean()
# Out:
# 2.875

# %% [markdown]
# *  method groupby() to split the values into two groups corresponding to dogs and cats, and then compute the mean value independently for each group.

# %%
df.groupby('A')['C'].mean()
# Out:
# A
# cat    3.333333
# dog    2.600000
# Name: C, dtype: float64

# %%
df['A']=='dog'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# Name: A, dtype: bool

# %%
df.loc[df['A']=='dog','C'].mean()
# Out:
# 2.6

# %% [markdown]
# * More advanced groupby approaches

# %%
df_csv = pd.read_csv('songs_requested.csv')
df_csv
# Out:
#         Musician                        Name  Decade  Requested
# 0   Led Zeppelin          Stairway to Heaven      70        435
# 1   Led Zeppelin                     Kashmir      70        284
# 2   Led Zeppelin              Immigrant Song      70        129
# 3   Led Zeppelin            Whole Lotta Love      60        337
# 4   Led Zeppelin                   Black Dog      70        302
# 5   Led Zeppelin        Good Times Bad Times      60        220
# 6   Led Zeppelin                   Moby Dick      60         93
# 7   Led Zeppelin                   Ramble On      60        144
# 8   Led Zeppelin                 All My Love      70        396
# 9   Led Zeppelin  The Song Remains the Same       70        178
# 10  Led Zeppelin       I Can't Quit You Baby      60         65
# 11   David Bowie                Space Oddity      60        194
# 12   David Bowie                 Rebel Rebel      70        172
# 13   David Bowie              Under Pressure      80        151
# ...

# %%
df_csv.groupby('Musician')['Requested'].describe()
# Out:
#               count        mean         std    min     25%    50%     75%  \
# Musician
# Bob Dylan       3.0  210.666667   78.678671  143.0  167.50  192.0  244.50
# David Bowie     6.0  165.166667   32.046321  107.0  156.25  177.5  183.75
# Led Zeppelin   11.0  234.818182  124.607237   65.0  136.50  220.0  319.50
#
#                 max
# Musician
# Bob Dylan     297.0
# David Bowie   194.0
# Led Zeppelin  435.0

# %% [markdown]
# *  We can do this by using .agg() and passing it a lambda function.
# * to_frame() turns a series into a data frame.
# * combine several aggregators  合并几个聚合器

# %%
df_csv.groupby('Musician')['Decade'].agg(lambda x: str(min(x))+"-"+str(max(x))).to_frame()
# Out:
#              Decade
# Musician
# Bob Dylan     60-70
# David Bowie   60-90
# Led Zeppelin  60-70

# %%
grouped_df=df_csv.groupby('Musician').agg({'Name': 'count',
                                    'Decade': lambda x: str(min(x))+"-"+str(max(x)), 
                                    'Requested': ['sum', 'max', np.mean]}
                                    )
grouped_df
# Out:
#               Name   Decade Requested
#              count <lambda>       sum  max        mean
# Musician
# Bob Dylan        3    60-70       632  297  210.666667
# David Bowie      6    60-90       991  194  165.166667
# Led Zeppelin    11    60-70      2583  435  234.818182

# %%
# renaming some columns
grouped_df.rename(columns={"count":"Total",
                           "<lambda>":"span"})
# Out:
#               Name Decade Requested
#              Total   span       sum  max        mean
# Musician
# Bob Dylan        3  60-70       632  297  210.666667
# David Bowie      6  60-90       991  194  165.166667
# Led Zeppelin    11  60-70      2583  435  234.818182

# %% [markdown]
# Missing values
# ---
# we simply mean a value that is null or not present.

# %%
df = pd.DataFrame(np.random.randint(10, size=(3, 3)), index=['a', 'c', 'e'], columns=['A', 'B', 'C'])

df
# Out:
#    A  B  C
# a  1  8  6
# c  9  6  2
# e  6  1  3

# %%
df2 = df.reindex(['a', 'b', 'c', 'd', 'e', 'f'])

# %%
df2
# Out:
#      A    B    C
# a  1.0  8.0  6.0
# b  NaN  NaN  NaN
# c  9.0  6.0  2.0
# d  NaN  NaN  NaN
# e  6.0  1.0  3.0
# f  NaN  NaN  NaN

# %% [markdown]
# * The isnull() method shows returns a True/False value for each entry of the DataFrame, depending on whether the value is missing or not.

# %%
df2.isnull()
# Out:
#        A      B      C
# a  False  False  False
# b   True   True   True
# c  False  False  False
# d   True   True   True
# e  False  False  False
# f   True   True   True

# %% [markdown]
# * use the isnull() method for is to count the number of missing values in each column of a DataFrame.

# %%
df2.isnull().sum()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df2.isnull().sum(axis=1)
# Out:
# a    0
# b    3
# c    0
# d    3
# e    0
# f    3
# dtype: int64

# %%
df2['A']
# Out:
# a    1.0
# b    NaN
# c    9.0
# d    NaN
# e    6.0
# f    NaN
# Name: A, dtype: float64

# %%
df2[df2['A'].isnull()]
# Out:
#     A   B   C
# b NaN NaN NaN
# d NaN NaN NaN
# f NaN NaN NaN

# %%
# The default setting for the dropna() method is to drop a row if any of its values are missing. 
df2.dropna()  #deal with missing values is to just drop any observations that contain them
# Out:
#      A    B    C
# a  1.0  8.0  6.0
# c  9.0  6.0  2.0
# e  6.0  1.0  3.0

# %%
# drop/delete a row if it has a missing value in all of the columns
df2.dropna(how='all')   # set to any or all
# Out:
#      A    B    C
# a  1.0  8.0  6.0
# c  9.0  6.0  2.0
# e  6.0  1.0  3.0

# %%
# drop a row if it has a missing value in column 'A'
df2.dropna(subset=['A'])
# Out:
#      A    B    C
# a  1.0  8.0  6.0
# c  9.0  6.0  2.0
# e  6.0  1.0  3.0

# %%
# drop a row if it has a missing value in column 'A' or column B
df2.dropna(subset=['A','B'])
# Out:
#      A    B    C
# a  1.0  8.0  6.0
# c  9.0  6.0  2.0
# e  6.0  1.0  3.0

# %%
# drop a row if it has a missing value in both column 'A' and column B
 df2.dropna(subset=['A','B'], how='all')
# Out:
#      A    B    C
# a  1.0  8.0  6.0
# c  9.0  6.0  2.0
# e  6.0  1.0  3.0

# %% [markdown]
# * Instead of just dropping rows with missing values we can opt to replace the missing values by some other specified values.

# %%
df2.fillna(value=0)
# Out:
#      A    B    C
# a  1.0  8.0  6.0
# b  0.0  0.0  0.0
# c  9.0  6.0  2.0
# d  0.0  0.0  0.0
# e  6.0  1.0  3.0
# f  0.0  0.0  0.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

np.linspace(0, 5, 2)
#array([ 0.,  5.])
np.linspace(0, 5, 9)
#array([ 0.   ,  0.625,  1.25 ,  1.875,  2.5  ,  3.125,  3.75 ,  4.375,  5.   ])

X = np.linspace(-np.pi, np.pi)
Y = np.sin(X) + np.cos(X)

plt.plot(X,Y);

# %%
plt.plot(X,Y, color='red', linewidth=2.0);

# %%
plt.plot(X,Y, color='red', linewidth=2.0);

plt.xlim(-4,4);

# %%
plt.plot(X,Y, color='red', linewidth=2.0)
plt.xlim(-4,4)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi]);

# %%
plt.plot(X,Y, color='red', linewidth=2.0)
plt.xlim(-4,4)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], ['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
# Out:
# ([<matplotlib.axis.XTick at 0x1d50909f438>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
plt.plot(X,Y, color='red', linewidth=2.0)
plt.xlim(-4,4)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], ['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
plt.title('The function $f(x)=\sin(x) + \cos(x)$');

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# np.linspace(0, 5, 2)
#array([ 0.,  5.])

X = np.linspace(-15, 15)
Y1 = np.sin(X) / X
Y2 = 2*np.sin(X) / X
Y3 = 3*np.sin(X) / X

# plt.plot(X,Y1, color='blue',linestyle='--', linewidth=2.0);
# plt.plot(X,Y2, color='green',linestyle='-.', linewidth=2.0);
# plt.plot(X,Y2, color='red',linestyle='-',marker='*', linewidth=2.0);
plt.plot(X,Y1,'--',label='sin(x)/x)')
plt.plot(X,Y2,'-.g',label='2.sin(x)/x)')
plt.plot(X,Y3,'-ro',label='3.sin(x)/x)')

plt.ylim(-1,3.5)
plt.yticks([-1,0,1,2,3])#,['$-\pi$', '$-\pi/2$', '$0$', '$\pi/2$', '$\pi$'])
plt.legend()
plt.show()
