# %% [markdown]
# # Plot pandas dataframe with subplots (subplots=True)
#
# https://stackoverflow.com/questions/33959124/plot-pandas-dataframe-with-subplots-subplots-true-place-legend-and-use-tight

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Generate random data
df = pd.DataFrame(np.random.randn(96,12),
                  columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J',
                           'K', 'L'])

df
# Out:
#            A         B         C         D         E         F         G  \
# 0  -0.654225  1.242586  0.508234  0.590799 -0.469457  0.979003 -0.247488
# 1   1.407437  1.130944  0.678906 -1.106147  0.993292  0.141633  0.504849
# 2  -0.605532  0.543563 -0.394799 -0.893061  1.063961 -0.378167  0.306291
# 3  -0.052019 -1.164496 -1.249418 -0.658451 -1.180358  1.505390 -0.808210
# 4   0.062574 -0.451163  0.112463 -1.411994 -0.185772  0.915674  0.611872
# ..       ...       ...       ...       ...       ...       ...       ...
# 91 -0.049947 -0.456425  0.770799 -2.010870  0.135424  1.153197  0.482809
# 92  0.452845 -0.659287  0.554973  0.766217  0.662608  3.443818  1.219150
# 93 -1.689930 -0.336404  0.441660  0.724153 -0.521778  0.145250 -0.099241
# 94  1.174013 -2.283319  0.043471 -0.325040 -0.418272  0.025231  0.357936
# 95  1.284027 -0.738895  0.306200 -2.410195  1.359336 -1.285613 -0.399684
#
#            H         I         J         K         L
# 0  -0.414908  0.455387 -1.583405  2.201093  1.021473
# 1   1.124001 -0.664126  0.116650 -0.530515  0.043140
# 2   0.777306  1.569545  0.675396 -1.828174 -1.440851
# 3  -0.193048 -0.535370  0.079265  0.199151 -1.617237
# 4  -0.472932  0.774080  0.533251 -0.202287 -1.627156
# ..       ...       ...       ...       ...       ...
# 91  1.158611 -2.001885 -0.697618  1.148598 -0.161273
# 92  0.396564 -0.860641  0.996275  1.784332 -0.750017
# 93  0.626010 -1.468213 -1.916158 -0.490986  1.048750
# 94  0.374450  0.206541 -1.772949  0.354542 -1.236119
# 95  1.661126 -2.388412  0.824587 -1.142987  0.479111
#
# [96 rows x 12 columns]

# %%
# Plotting
plt.figure(figsize=(15, 15))
df.plot(kind='line', subplots=True, grid=True, title="Sample Data (Unit)",
    layout=(4, 3), sharex=True, sharey=False, legend=False,    
    style=['r', 'r', 'r', 'g', 'g', 'g', 'b', 'b', 'b', 'r', 'r', 'r'],
    xticks=np.arange(0, len(df), 16))

[ax.legend(loc=1) for ax in plt.gcf().axes]

plt.tight_layout()

# %%
# Plotting
plt.figure(figsize=(15, 15))

df.plot(kind='line', subplots=True, grid=True, title="Sample Data (Unit)",
    layout=(4, 3), sharex=True, sharey=False, legend=False,    
    style=['r', 'r', 'r', 'g', 'g', 'g', 'b', 'b', 'b', 'r', 'r', 'r'],
    xticks=np.arange(0, len(df), 16))

[ax.legend(loc=1) for ax in plt.gcf().axes]

# plt.tight_layout()
# Out:
# [<matplotlib.legend.Legend at 0x1bb76303c88>,
#  <matplotlib.legend.Legend at 0x1bb77028358>,
#  <matplotlib.legend.Legend at 0x1bb770c7c50>,
#  <matplotlib.legend.Legend at 0x1bb770c7908>,
#  <matplotlib.legend.Legend at 0x1bb770abf60>,
#  <matplotlib.legend.Legend at 0x1bb770cd748>,
#  <matplotlib.legend.Legend at 0x1bb770cdf60>,
#  <matplotlib.legend.Legend at 0x1bb770b6a20>,
#  <matplotlib.legend.Legend at 0x1bb770dec50>,
#  <matplotlib.legend.Legend at 0x1bb770e74a8>,
#  <matplotlib.legend.Legend at 0x1bb770e7cc0>,
#  <matplotlib.legend.Legend at 0x1bb770f3518>]
